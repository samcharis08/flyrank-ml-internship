# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose Lane 4 (CTR / Engagement Opportunity Scoring) because the starter notebook showed that click-through rate (CTR) changes noticeably across different search position tiers, which I found interesting. My observation was that CTR decreases significantly as pages move further down the search results. I believe this lane can help the SEO team identify pages that receive fewer clicks than expected for their position and prioritize them for review.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision:
#
# Decide which pages should be reviewed first because they are getting fewer clicks than expected for their position.
#
# Who acts:
#
# The SEO manager.
#
# Action:
#
# The SEO manager reviews the page title, meta description, and content to improve its CTR.
#
# Cost of a wrong call:
#
# The SEO team could waste time working on pages that do not need improvement or miss pages that actually need attention.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
visible = df[df["impressions_90d"] >= 100]

ctr_by_pos = (
    visible.groupby("position_tier")["ctr"]
    .mean()
    .sort_values(ascending=False)
)

print(ctr_by_pos.round(4))
# Out:
# position_tier
# page_1      0.3548
# top_3       0.3341
# striking    0.2558
# page_3_5    0.1424
# deep        0.0554
# Name: ctr, dtype: float64

# %% [markdown]
# From the starter dataset, using pages with at least 100 impressions, the average CTR decreased from 0.3548 for page_1 pages to 0.0554 for deep pages. These numbers show that CTR becomes lower as pages appear lower in the search results. This suggests that search position is associated with the number of clicks a page receives and is worth investigating further over the next seven weeks.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work observes and measures how CTR varies across different search position tiers.It can provide directional, decision-support evidence to help identify pages that may need review. However, this work cannot prove that a lower search position causes a lower CTR, and it cannot predict Google's algorithm or explain exactly why pages rank where they do.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
